# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import SimpleRNN, Dense, Input
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error

# %%
file_path = r"C:\Users\kimge\OneDrive\문서\Desktop\김 건\가천대학교\2025년 4학년 1학기_시간표\인공지능개론\13_week\AAME.csv"
df = pd.read_csv(file_path)

# %%
df
# Out:
#              Date  Open  High   Low  Close  Adj Close  Volume
# 0      1980-03-17  0.00  4.05  3.85   3.85   3.213167   15000
# 1      1980-03-18  0.00  4.00  3.80   3.80   3.171437   10200
# 2      1980-03-19  0.00  4.05  3.85   3.85   3.213167   33500
# 3      1980-03-20  0.00  4.00  3.80   3.80   3.171437    8700
# 4      1980-03-21  0.00  3.95  3.75   3.75   3.129709   12700
# ...           ...   ...   ...   ...    ...        ...     ...
# 10093  2020-03-26  2.29  2.29  2.08   2.28   2.280000    1600
# 10094  2020-03-27  2.25  2.25  2.21   2.25   2.250000     500
# 10095  2020-03-30  2.25  2.25  2.13   2.13   2.130000     400
# 10096  2020-03-31  2.11  2.11  2.11   2.11   2.110000     300
# 10097  2020-04-01  2.11  2.15  2.11   2.15   2.150000     600
#
# [10098 rows x 7 columns]

# %%
df['Date'] = pd.to_datetime(df['Date'])
df = df.sort_values('Date')

# %%
features = ['Open', 'High', 'Low', 'Close']
data = df[features].to_numpy()

# %%
scaler = MinMaxScaler()
scaled_data = scaler.fit_transform(data)

# %%
def make_sequence(data, window_size):
    X, y = [], []
    for i in range(len(data) - window_size):
        X.append(data[i:i+window_size])
        y.append(data[i+window_size][-1])  # 다음날 Close (마지막 열)
    return np.array(X), np.array(y)

window_size = 5
X, y = make_sequence(scaled_data, window_size)

# %%
split = int(len(X) * 0.8)
X_train, X_test = X[:split], X[split:]
y_train, y_test = y[:split], y[split:]

# %%
model = Sequential([
    Input(shape=(window_size, len(features))),
    SimpleRNN(64, activation='tanh'),
    Dense(1)
])

model.compile(optimizer='adam', loss='mse')
model.fit(X_train, y_train, epochs=30, batch_size=16, validation_split=0.1)
# Out:
# Epoch 1/30
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - loss: 0.0131 - val_loss: 2.6266e-05
# Epoch 2/30
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 1.1992e-04 - val_loss: 2.3861e-05
# Epoch 3/30
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 1.2532e-04 - val_loss: 2.2130e-05
# Epoch 4/30
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 1.3741e-04 - val_loss: 2.1789e-05
# Epoch 5/30
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 1.3525e-04 - val_loss: 2.7897e-05
# Epoch 6/30
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 1.4548e-04 - val_loss: 3.6726e-05
# Epoch 7/30
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 1.2325e-04 - val_loss: 2.0994e-05
# Epoch 8/30
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 1.2982e-04 - val_loss: 6.8069e-05
# Epoch 9/30
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 1.1927e-04 - val_loss: 2.0579e-05
# Epoch 10/30
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 1.2685e-04 - val_loss: 2.0864e-05
# Epoch 11/30
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 9.7454e-05 - val_loss: 2.2616e-05
# Epoch 12/30
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 1.1079e-04 - val_loss: 3.2703e-05
# Epoch 13/30
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 1.1416e-04 - val_loss: 2.0263e-05
# Epoch 14/30
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 1.0571e-04 - val_loss: 6.6678e-05
# Epoch 15/30
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 1.1325e-04 - val_loss: 4.0054e-05
# Epoch 16/30
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 1.1370e-04 - val_loss: 2.0747e-05
# Epoch 17/30
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 1.3200e-04 - val_loss: 3.2475e-05
# Epoch 18/30
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 1.0851e-04 - val_loss: 2.4220e-05
# Epoch 19/30
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 1.0083e-04 - val_loss: 5.3190e-05
# Epoch 20/30
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 1.1964e-04 - val_loss: 2.0501e-05
# Epoch 21/30
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 1.2909e-04 - val_loss: 2.3288e-05
# Epoch 22/30
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 1.1946e-04 - val_loss: 2.2586e-05
# Epoch 23/30
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 1.0096e-04 - val_loss: 2.5926e-05
# Epoch 24/30
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 1.0860e-04 - val_loss: 4.1532e-05
# Epoch 25/30
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 1.0049e-04 - val_loss: 3.0502e-05
# Epoch 26/30
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 1.0119e-04 - val_loss: 4.5888e-05
# Epoch 27/30
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 1.0438e-04 - val_loss: 2.1943e-05
# Epoch 28/30
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 1.1077e-04 - val_loss: 2.5461e-05
# Epoch 29/30
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 1.0344e-04 - val_loss: 3.4499e-05
# Epoch 30/30
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 1.0688e-04 - val_loss: 2.2735e-05

# %%
y_pred = model.predict(X_test)
# Out:
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step

# %%
def inverse_close(scaled_close):
    dummy = np.zeros((len(scaled_close), len(features)))  # features = 4
    dummy[:, -1] = scaled_close.reshape(-1)               # 마지막 열에 Close만
    return scaler.inverse_transform(dummy)[:, -1]

# %%
y_test_inv = inverse_close(y_test)
y_pred_inv = inverse_close(y_pred)

# %%
mse = mean_squared_error(y_test_inv, y_pred_inv)
print(f"\n✅ RNN Test MSE: {mse:.4f}")
# Out:
# ✅ RNN Test MSE: 0.0103

# %%
plt.figure(figsize=(10,5))
plt.plot(y_test_inv, label='Actual Close Price')
plt.plot(y_pred_inv, label='Predicted Close Price (RNN)')
plt.title('RNN Multi-Feature Close Price Prediction')
plt.xlabel('Time Step')
plt.ylabel('Price')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()
